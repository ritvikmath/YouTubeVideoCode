# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %% [markdown]
# # Goal: Sample from bivariate Normal

# %%
automatic_samples = np.random.multivariate_normal([0,0], [[1, 0.5], [0.5,1]], 10000)

# %%
plt.scatter(automatic_samples[:,0], automatic_samples[:,1], s=5)

# %% [markdown]
# # Gibbs Sampling

# %%
samples = {'x': [1], 'y': [-1]}

num_samples = 10000

for _ in range(num_samples):
    curr_y = samples['y'][-1]
    new_x = np.random.normal(curr_y/2, np.sqrt(3/4))
    new_y = np.random.normal(new_x/2, np.sqrt(3/4))
    samples['x'].append(new_x)
    samples['y'].append(new_y)

# %%
plt.scatter(samples['x'], samples['y'], s=5)

# %%
plt.hist(automatic_samples[:,0], bins=20, density=True, alpha=0.5)
plt.hist(samples['x'], bins=20, density=True, alpha=0.5)
# Out:
# (array([0.00107976, 0.00377917, 0.01106756, 0.03050329, 0.06937473,
#         0.1303813 , 0.19894621, 0.29315547, 0.36549955, 0.39762248,
#         0.35848109, 0.32878763, 0.21784205, 0.15143667, 0.08287176,
#         0.03779168, 0.01295715, 0.00620863, 0.0013497 , 0.00053988]),
#  array([-3.54826107, -3.17784621, -2.80743136, -2.43701651, -2.06660166,
#         -1.6961868 , -1.32577195, -0.9553571 , -0.58494225, -0.21452739,
#          0.15588746,  0.52630231,  0.89671717,  1.26713202,  1.63754687,
#          2.00796172,  2.37837658,  2.74879143,  3.11920628,  3.48962113,
#          3.86003599]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(automatic_samples[:,1], bins=20, density=True, alpha=0.5)
plt.hist(samples['y'], bins=20, density=True, alpha=0.5)
# Out:
# (array([0.00284925, 0.01339147, 0.02621309, 0.05556036, 0.10969609,
#         0.17465898, 0.2607063 , 0.34675363, 0.39775519, 0.39091699,
#         0.36185465, 0.27495255, 0.18577105, 0.12508204, 0.06838198,
#         0.03105682, 0.0159558 , 0.00541357, 0.00142462, 0.0011397 ]),
#  array([-3.19075436, -2.8398198 , -2.48888524, -2.13795068, -1.78701612,
#         -1.43608156, -1.085147  , -0.73421244, -0.38327789, -0.03234333,
#          0.31859123,  0.66952579,  1.02046035,  1.37139491,  1.72232947,
#          2.07326403,  2.42419859,  2.77513315,  3.12606771,  3.47700226,
#          3.82793682]),
#  <a list of 20 Patch objects>)

# %%
plt.scatter(automatic_samples[:-1,0], automatic_samples[1:,0], s=5)
print(pearsonr(automatic_samples[:-1,0], automatic_samples[1:,0])[0])
# Out:
# 0.01176788097254983

# %%
plt.scatter(samples['x'][:-1], samples['x'][1:], s=5)
print(pearsonr(samples['x'][:-1], samples['x'][1:])[0])
# Out:
# 0.23825766737857293
